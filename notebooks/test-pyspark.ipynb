# %%
from pathlib import Path

from dotenv import load_dotenv
from pyspark.sql import SparkSession

# %%
# Cargar las variables de entorno desde el archivo .env
load_dotenv()
# Out:
# True

# %%
BASE_DIR = Path.cwd().parent

# %%
spark = (
    SparkSession.builder.appName("Spark Flights ETL").master("local[8]").getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/04 03:10:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = (
    spark.read.option("header", "true")
    .option("inferSchema", "true")
    .csv(str(BASE_DIR / "flights-subset.csv"))
)

# %%
df.limit(5).toPandas()
# Out:
#    Month  DayofMonth  DayOfWeek  FlightDate Origin             OriginCity  \
# 0      4           8          7  2018-04-08    MSP        Minneapolis, MN
# 1      4          23          1  2018-04-23    PHX            Phoenix, AZ
# 2      3          28          3  2018-03-28    DFW  Dallas/Fort Worth, TX
# 3      3          17          6  2018-03-17    ECP        Panama City, FL
# 4      4          27          5  2018-04-27    LGB         Long Beach, CA
#
#   Dest        DestCity  DepTime  DepDelay  ...  CancellationCode  Diverted  \
# 0  BJI     Bemidji, MN     2200      -5.0  ...              None       0.0
# 1  ORD     Chicago, IL      715      -5.0  ...              None       0.0
# 2  MLU      Monroe, LA     1429      -6.0  ...              None       0.0
# 3  IAH     Houston, TX     1424      -8.0  ...              None       0.0
# 4  SMF  Sacramento, CA     1644       4.0  ...              None       0.0
#
#    ActualElapsedTime AirTime  Distance  CarrierDelay  WeatherDelay  NASDelay  \
# 0               85.0    37.0     199.0           0.0           0.0      16.0
# 1              196.0   176.0    1440.0           NaN           NaN       NaN
# 2               72.0    48.0     293.0           NaN           NaN       NaN
# 3              134.0   110.0     572.0           NaN           NaN       NaN
# 4               74.0    61.0     387.0           NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            0.0                0.0
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
#
# [5 rows x 23 columns]
